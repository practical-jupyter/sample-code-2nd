# %% [markdown]
# ## 棒グラフ

# %%
# リスト 4.5.1　棒グラフの描画

import matplotlib.pyplot as plt

# %matplotlib inline

# 棒グラフの描画
fig, ax = plt.subplots(1, 1)
ticks = [1, 2, 3]
values = [100, 200, 250]
ax.bar(ticks, values)

# %%
# リスト 4.5.2　目盛りラベルを設定した棒グラフの描画

fig, ax = plt.subplots(1, 1)
ax.bar(ticks, values, tick_label=ticks)

# %%
# リスト 4.5.3　横向きの棒グラフの描画

fig, ax = plt.subplots(1, 1)
ax.barh(ticks, values, tick_label=ticks)

# %%
# リスト 4.5.4　X 値として文字列を指定して棒グラフを描画

fig, ax = plt.subplots(1, 1)
labels = ["Orange", "Lemon", "Lime"]
values = [100, 200, 250]
ax.bar(labels, values)

# %%
# リスト 4.5.5　辞書形式のデータを使ってラベルを指定

fig, ax = plt.subplots(1, 1)
data = {"Orange": 100, "Lemon": 200, "Lime": 250}
ax.bar(data.keys(), data.values())

# %%
# リスト 4.5.6　複数グループの棒グラフを描画（失敗例）

import numpy as np

# データセットの作成
x = [1, 2]
y1 = [1, 4]
y2 = [2, 5]
y3 = [3, 6]
labels = ["A", "B"]

# 複数グループの棒グラフの描画
fig, ax = plt.subplots(1, 1)
ax.bar(x, y1, label="y1", tick_label=labels)
ax.bar(x, y2, label="y2")
ax.bar(x, y3, label="y3")
ax.legend(bbox_to_anchor=(1, 1))

# %%
# リスト 4.5.7　複数グループの棒グラフの描画

fig, ax = plt.subplots(1, 1)

# データセットの作成
array_x = np.array(x)
array_y1 = np.array(y1)
array_y2 = np.array(y2)
array_y3 = np.array(y3)
labels = ["A", "B"]

# 棒の幅
bar_width = 0.3

# 棒グラフの描画
ax.bar(array_x, array_y1, width=bar_width, label="y1")
ax.bar(
    array_x + bar_width,
    array_y2,
    width=bar_width,
    label="y2",
    tick_label=labels,
)
ax.bar(array_x + bar_width * 2, array_y3, width=bar_width, label="y3")
ax.legend()

# %%
# リスト 4.5.8　積み上げ棒グラフの描画

# 積み上げ棒グラフの描画
fig, ax = plt.subplots(1, 1)
sum_y1y2 = array_y1 + array_y2
sum_y1y2y3 = sum_y1y2 + array_y3
ax.bar(array_x, sum_y1y2y3, label="y3", tick_label=x)
ax.bar(array_x, sum_y1y2, label="y2")
ax.bar(array_x, array_y1, label="y1")
ax.legend()

# %%
# リスト 4.5.9　bottom オプションを用いて積み上げ棒グラフを描画

figure, ax = plt.subplots(1, 1)
ax.bar(array_x, sum_y1y2y3, label="y3", tick_label=x)
ax.bar(array_x, array_y2, bottom=y1, label="y2")
ax.bar(array_x, array_y1, label="y1")
ax.legend()

# %%
# リスト 4.5.10　anime_master.csv ファイルの読み込み

from urllib.parse import urljoin
import pandas as pd

base_url = "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
anime_master_csv = urljoin(base_url, "anime_master.csv")
df_master = pd.read_csv(anime_master_csv)
df_master.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                          Gintama'
#
#                                                genre   type  episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie         1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV        64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV        51    9.25
# 3                                   Sci-Fi, Thriller     TV        24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV        51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
# リスト 4.5.11　メディア種別ごとの合計メンバ数の棒グラフを描画

fig, ax = plt.subplots(1, 1)
y = df_master.groupby("type")["members"].sum()
x = y.index
ax.bar(x, y)
ax.set_ylabel("合計のべメンバ数")

# %%
# リスト 4.5.12　anime_genre_top10_pivoted.csv ファイルの読み込み

base_url = "https://raw.githubusercontent.com/practical-jupyter/sample-data/master/anime/"
anime_genre_top10_pivoted_csv = urljoin(
    base_url, "anime_genre_top10_pivoted.csv"
)
df_master_genre = pd.read_csv(anime_genre_top10_pivoted_csv, index_col="genre")
df_master_genre
# Out:
#                    Movie     Music        ONA        OVA    Special  \
# genre
# Comedy         7293127.0   20860.0  1477266.0  5614758.0  6659293.0
# Action        10224960.0   77054.0   524907.0  5793680.0  3412689.0
# Drama          9034099.0  100734.0   188427.0  3043374.0  1915578.0
# Romance        5245386.0   42811.0   411331.0  3143167.0  2015820.0
# Supernatural   5452779.0    9189.0   192989.0  2696715.0  2336723.0
# Fantasy        8019406.0   43962.0   188937.0  2754224.0  2504131.0
# Shounen        5698808.0       NaN    97833.0  3861296.0  2591988.0
# School         1512533.0    5496.0   523223.0  2417660.0  2661425.0
# Adventure      9485223.0   42829.0    70431.0  2373765.0  2052024.0
# Sci-Fi         6967146.0  154801.0   415311.0  3358525.0  1616450.0
#
#                       TV
# genre
# Comedy        65420862.0
# Action        63364032.0
# Drama         41011557.0
# Romance       40703388.0
# Supernatural  38956520.0
# Fantasy       34932563.0
# Shounen       35532847.0
# School        35489099.0
# Adventure     27529975.0
# Sci-Fi        28072322.0

# %%
# リスト 4.5.13　メディア種別・ジャンル別棒グラフの描画

genres = df_master_genre.index  # ジャンルリスト
types = df_master_genre.columns  # メディア種別リスト
genre_number = len(genres)  # ジャンル数
type_number = len(types)  # メディア種別数
fig, ax = plt.subplots(1, 1, figsize=(16, 3))
total_bar_width = 0.8  # ジャンルグループ全体の棒の幅
bar_width = total_bar_width / type_number  # 各メディア種別の棒の幅
x = np.arange(1, genre_number + 1)  # 各ジャンルのX基準位置

for type_ in types:
    data = df_master_genre[type_]
    ax.bar(x, data, width=bar_width, align="edge", label=type_)
    x = x + bar_width

ax.set_xticks(x + total_bar_width / 2)
ax.set_xticklabels(genres)
ax.set_ylabel("のべメンバ数")
ax.legend()

# %%
# リスト 4.5.14　メディア種別・ジャンル別棒グラフの描画（対数軸）

fig, ax = plt.subplots(1, 1, figsize=(16, 3))

for type_ in types:
    data = df_master_genre[type_]
    ax.bar(x, data, width=bar_width, align="edge", label=type_)
    x = x + bar_width

ax.set_yscale("log")
ax.set_xticks(x + total_bar_width / 2)
ax.set_xticklabels(genres)
ax.set_ylabel("のべメンバ数")
ax.legend(bbox_to_anchor=(1, 1))

# %%
# リスト 4.5.15　メディア種別・ジャンル別積み上げ棒グラフの描画

fig, ax = plt.subplots(1, 1, figsize=(15, 3))

for i, type_ in enumerate(types):
    # i列目から最終列までの和を計算
    values = df_master_genre.iloc[:, i:type_number].sum(axis=1)
    ax.bar(genres, values, label=type_)

ax.set_ylabel("のべメンバ数")
ax.legend(bbox_to_anchor=(1, 1))
