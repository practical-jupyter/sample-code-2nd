# %% [markdown]
# ## 7.3: ジョイントグリッドの活用

# %%
# リスト 7.3.1　JointGrid クラスによるグラフの描画

import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset("tips")
sns.JointGrid(data=tips, x="total_bill", y="tip")

# %%
# リスト 7.3.2　散布図の辺にグラフを追加

joint_grid = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid.plot(plt.scatter, sns.distplot)

# %%
# リスト 7.3.3　plot_joint() メソッドと plot_marginals() メソッドを利用したグラフの描画

joint_grid = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid.plot_joint(plt.scatter)
joint_grid.plot_marginals(sns.distplot)

# %%
# リスト 7.3.4　Matplotlib のメソッドを利用したグラフの描画

joint_grid_ax = sns.JointGrid(data=tips, x="total_bill", y="tip")
joint_grid_ax.plot_joint(sns.regplot)
joint_grid_ax.ax_marg_x.hist(tips["total_bill"])
joint_grid_ax.ax_marg_y.boxplot(tips["tip"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f32e7bc3a90>,
#   <matplotlib.lines.Line2D at 0x7f32e7b70450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f32e7b70990>,
#   <matplotlib.lines.Line2D at 0x7f32e7b70ed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f32e7ba4a50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f32e7b77490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f32e7b779d0>],
#  'means': []}
